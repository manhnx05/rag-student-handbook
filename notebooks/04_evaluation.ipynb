# %% [markdown]
# # RAG Evaluation
#
# Load evaluation questions and compare retrieved sources with ground truth.

# %%
import json
from pathlib import Path

evaluation_dir = Path('../data/evaluation')
questions = json.loads((evaluation_dir / 'questions.json').read_text(encoding='utf-8'))
len(questions)
