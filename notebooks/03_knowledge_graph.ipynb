# %% [markdown]
# # Knowledge Graph Inspection
#
# Review extracted entity and relationship records before Neo4j ingestion.

# %%
from pathlib import Path

entity_dir = Path('../data/processed/entities')
list(entity_dir.iterdir())
