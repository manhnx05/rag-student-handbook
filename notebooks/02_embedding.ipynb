# %% [markdown]
# # Embedding Inspection
#
# Inspect chunk counts and embedding configuration.

# %%
import json
from pathlib import Path

chunks = json.loads(Path('../data/processed/chunks.json').read_text(encoding='utf-8'))
len(chunks)
